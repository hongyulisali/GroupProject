# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
df= pd.read_csv("Electric_Vehicle_Population_Data.csv")
df.head(20)
# Out:
#     VIN (1-10)     County       City State  ZIP Code  Model Year    Make  \
# 0   WA1VABGE6K       King    Seattle    WA     98144        2019    Audi
# 1   1N4BZ0CP2H       King    Bothell    WA     98011        2017  Nissan
# 2   1N4AZ0CP1G       King    Seattle    WA     98125        2016  Nissan
# 3   WBY7Z2C51J       King    Seattle    WA     98115        2018     BMW
# 4   1N4AZ0CP4G       King    Redmond    WA     98052        2016  Nissan
# 5   1N4AZ0CP6D       King    Seattle    WA     98125        2013  Nissan
# 6   JHMZC5F34J       King  Shoreline    WA     98155        2018   Honda
# 7   KNDJX3AE4H       King    Seattle    WA     98136        2017     Kia
# 8   KNDJX3AE4J       King  Sammamish    WA     98074        2018     Kia
# 9   KNDJX3AE3H       King    Seattle    WA     98126        2017     Kia
# 10  KNDJX3AE3J       King    Redmond    WA     98052        2018     Kia
# 11  5YJ3E1EB8K  Snohomish    Everett    WA     98204        2019   Tesla
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        VIN (1-10)   County        City State  ZIP Code  Model Year    Make  \
# 0      WA1VABGE6K     King     Seattle    WA     98144        2019    Audi
# 1      1N4BZ0CP2H     King     Bothell    WA     98011        2017  Nissan
# 2      1N4AZ0CP1G     King     Seattle    WA     98125        2016  Nissan
# 3      WBY7Z2C51J     King     Seattle    WA     98115        2018     BMW
# 4      1N4AZ0CP4G     King     Redmond    WA     98052        2016  Nissan
# ...           ...      ...         ...   ...       ...         ...     ...
# 54890  5YJ3E1EA1J    Clark   Vancouver    WA     98662        2018   Tesla
# 54891  JTDKARFP8H  Whatcom  Bellingham    WA     98229        2017  Toyota
# 54892  5YJSA1S21F     King     Redmond    WA     98052        2015   Tesla
# 54893  3FA6P0SU7D     King      Auburn    WA     98092        2013    Ford
# 54894  1N4BZ1CPXK     King     Seattle    WA     98144        2019  Nissan
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.boxplot(column='Electric Range', by='Make' )

# %%
sns.lmplot(x='Electric Range', y='Base MSRP', data=df)

# %%
sns.lmplot(x='Model Year', y='Electric Range', data=df)

# %%
 df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   0
# State                                                  0
# ZIP Code                                               0
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                            456
# Legislative District                                 117
# DOL Vehicle ID                                         0
# Vehicle Location                                       2
# dtype: int64

# %%
df_no_missing = df.dropna()
df_no_missing.head()
# Out:
#    VIN (1-10) County     City State  ZIP Code  Model Year    Make   Model  \
# 0  WA1VABGE6K   King  Seattle    WA     98144        2019    Audi  e-tron
# 1  1N4BZ0CP2H   King  Bothell    WA     98011        2017  Nissan    Leaf
# 2  1N4AZ0CP1G   King  Seattle    WA     98125        2016  Nissan    Leaf
# 3  WBY7Z2C51J   King  Seattle    WA     98115        2018     BMW      i3
# 4  1N4AZ0CP4G   King  Redmond    WA     98052        2016  Nissan    Leaf
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             204
# 1           Clean Alternative Fuel Vehicle Eligible             107
# 2           Clean Alternative Fuel Vehicle Eligible              84
# ...

# %%
df_no_missing.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# ZIP Code                                             0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# dtype: int64

# %%
#df_no_missing.drop('VIN (1-10)','State','County','Legislative District','DOL Vehicle ID', axis=5)

# %%
df_no_missing.drop(columns=['VIN (1-10)','State','County','Legislative District','DOL Vehicle ID' ], inplace=True)
df_no_missing.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       City  ZIP Code  Model Year    Make   Model  \
# 0  Seattle     98144        2019    Audi  e-tron
# 1  Bothell     98011        2017  Nissan    Leaf
# 2  Seattle     98125        2016  Nissan    Leaf
# 3  Seattle     98115        2018     BMW      i3
# 4  Redmond     98052        2016  Nissan    Leaf
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
df_no_missing.to_csv(r'new_evdata.csv')
